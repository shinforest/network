# %% [markdown]
# # 認知症患者との会話を対象とした共起表現ネットワーク作成
# <h3>目標：認知症患者が使う語彙・フレーズを特徴を見つけたい。</h3>
# <h3>対象：認知症患者(女性、74才)との会話</h3>
#
# <h4>課題：データのクリーニング(動詞や指示語を消す)</h4>
# 　　　<h4>健常者の対話文も分析する</h4>
#    　 <h4>ネットワーク解析</h4>

# %% [markdown]
# <h2>ライブラリ読み込み</h2>

# %%
import MeCab
import sys
import pandas as pd
import re
import csv
from pathlib import Path
import itertools
import collections
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # 日本語フォント読み込み

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']

# %% [markdown]
# # <h1>データ読み込み</h1>

# %%
tagger = MeCab.Tagger()
termFreq = {}
file = 'controll#1.txt'
with open(file) as f:
    text = f.read()
text = re.sub('二十二歳', '22歳', text)
text = re.sub('十二歳', '22歳', text)
result = tagger.parse(text)
result
# Out:
# 'それぞれ\t名詞,副詞可能,*,*,*,*,それぞれ,ソレゾレ,ソレゾレ\n。\t記号,句点,*,*,*,*,。,。,。\nはい\t感動詞,*,*,*,*,*,はい,ハイ,ハイ\nぼく\t名詞,代名詞,一般,*,*,*,ぼく,ボク,ボク\nも\t助詞,係助詞,*,*,*,*,も,モ,モ\nや\t名詞,形容動詞語幹,*,*,*,*,や,ヤ,ヤ\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\nんで\t助詞,接続助詞,*,*,*,*,んで,ンデ,ンデ\nはい\t感動詞,*,*,*,*,*,はい,ハイ,ハイ\nこの\t連体詞,*,*,*,*,*,この,コノ,コノ\n企画\t名詞,サ変接続,*,*,*,*,企画,キカク,キカク\nは\t助詞,係助詞,*,*,*,*,は,ハ,ワ\n二\t名詞,数,*,*,*,*,二,ニ,ニ\n十\t名詞,数,*,*,*,*,十,ジュウ,ジュー\n分\t名詞,接尾,助数詞,*,*,*,分,フン,フン\n一\t名詞,数,*,*,*,*,一,イチ,イチ\n本\t名詞,接尾,助数詞,*,*,*,本,ホン,ホン\n勝負\t名詞,サ変接続,*,*,*,*,勝負,ショウブ,ショーブ\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n法力\t名詞,一般,*,*,*,*,法力,ホウリキ,ホーリキ\nで\t助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nねえ\t助詞,終助詞,*,*,*,*,ねえ,ネエ,ネー\n。\t記号,句点,*,*,*,*,。,。,。\nそう\t副詞,助詞類接続,*,*,*,*,そう,ソウ,ソー\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\nん\t名詞,非自立,一般,*,*,*,ん,ン,ン\nだ\t助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ\n。\t記号,句点,*,*,*,*,。,。,。\nうん\t感動詞,*,*,*,*,*,うん,ウン,ウン\nスタート\t名詞,サ変接続,*,*,*,*,スタート,スタート,スタート\nは\t助詞,係助詞,*,*,*,*,は,ハ,ワ\n凄い\t形容詞,自立,*,*,形容詞・アウオ段,基本形,凄い,スゴイ,スゴイ\n。\t記号,句点,*,*,*,*,。,。,。\n広い\t形容詞,自立,*,*,形容詞・アウオ段,基本形,広い,ヒロイ,ヒロイ\n物体\t名詞,一般,*,*,*,*,物体,ブッタイ,ブッタイ\nだ\t助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ\nな\t助詞,終助詞,*,*,*,*,な,ナ,ナ\n条例\t名詞,一般,*,*,*,*,条例,ジョウレイ,ジョーレイ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n意味\t名詞,サ変接続,*,*,*,*,意味,イミ,イミ\nだけ\t助詞,副助詞,*,*,*,*,だけ,ダケ,ダケ\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\nん\t名詞,非自立,一般,*,*,*,ん,ン,ン\nです\t助動詞,*,*,*,特殊・デス,基本形,です,デス,デス\nけど\t助詞,接続助詞,*,*,*,*,けど,ケド,ケド\nうん\tフィラー,*,*,*,*,*,うん,ウン,ウン\nイーロンマスク\t名詞,一般,*,*,*,*,*\nうん\t感動詞,*,*,*,*,*,うん,ウン,ウン\n超える\t動詞,自立,*,*,一段,基本形,超える,コエル,コエル\nか\t助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ\n超え\t動詞,自立,*,*,一段,未然形,超える,コエ,コエ\nない\t助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ\nか\t助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ\nとか\t助詞,並立助詞,*,*,*,*,とか,トカ,トカ\n宇宙\t名詞,一般,*,*,*,*,宇宙,ウチュウ,ウチュー\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\nどう\t副詞,助詞類接続,*,*,*,*,どう,ドウ,ドー\nする\t動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\nか\t助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ\nっていう\t助詞,格助詞,連語,*,*,*,っていう,ッテイウ,ッテユウ\n戦い\t名詞,一般,*,*,*,*,戦い,タタカイ,タタカイ\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n日本\t名詞,固有名詞,地域,国,*,*,日本,ニッポン,ニッポン\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n忠勝\t名詞,固有名詞,人名,名,*,*,忠勝,タダカツ,タダカツ\n俺\t名詞,代名詞,一般,*,*,*,俺,オレ,オレ\nさあ\t感動詞,*,*,*,*,*,さあ,サア,サー\nや\t助詞,並立助詞,*,*,*,*,や,ヤ,ヤ\n田中\t名詞,固有名詞,人名,姓,*,*,田中,タナカ,タナカ\n。\t記号,句点,*,*,*,*,。,。,。\nなく\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,ない,ナク,ナク\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n笑\t名詞,固有名詞,人名,名,*,*,笑,エミ,エミ\nいろんな\t連体詞,*,*,*,*,*,いろんな,イロンナ,イロンナ\n過ごし\t動詞,自立,*,*,五段・サ行,連用形,過ごす,スゴシ,スゴシ\n方\t名詞,接尾,特殊,*,*,*,方,カタ,カタ\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nて\t動詞,非自立,*,*,一段,連用形,てる,テ,テ\n。\t記号,句点,*,*,*,*,。,。,。\nなんか\tフィラー,*,*,*,*,*,なんか,ナンカ,ナンカ\n若い\t形容詞,自立,*,*,形容詞・アウオ段,基本形,若い,ワカイ,ワカイ\n部類\t名詞,一般,*,*,*,*,部類,ブルイ,ブルイ\nの\t助詞,格助詞,一般,*,*,*,の,ノ,ノ\nなっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nてる\t動詞,非自立,*,*,一段,基本形,てる,テル,テル\nらしい\t助動詞,*,*,*,形容詞・イ段,基本形,らしい,ラシイ,ラシイ\n使っ\t動詞,自立,*,*,五段・ワ行促音便,連用タ接続,使う,ツカッ,ツカッ\nてる\t動詞,非自立,*,*,一段,基本形,てる,テル,テル\nと\t助詞,格助詞,引用,*,*,*,と,ト,ト\nか\t助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ\nじゃ\t助詞,副助詞,*,*,*,*,じゃ,ジャ,ジャ\nなく\t助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n。\t記号,句点,*,*,*,*,。,。,。\nこれ\t名詞,代名詞,一般,*,*,*,これ,コレ,コレ\n以降\t名詞,副詞可能,*,*,*,*,以降,イコウ,イコー\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\nん\t名詞,非自立,一般,*,*,*,ん,ン,ン\nだ\t助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ\nね\t助詞,終助詞,*,*,*,*,ね,ネ,ネ\nアイラマイナス\t名詞,一般,*,*,*,*,*\nは\t助詞,係助詞,*,*,*,*,は,ハ,ワ\n以降\t名詞,副詞可能,*,*,*,*,以降,イコウ,イコー\nへ\t助詞,格助詞,一般,*,*,*,へ,ヘ,エ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n。\t記号,句点,*,*,*,*,。,。,。\nはい\t感動詞,*,*,*,*,*,はい,ハイ,ハイ\n。\t記号,句点,*,*,*,*,。,。,。\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n僕\t名詞,代名詞,一般,*,*,*,僕,ボク,ボク\nは\t助詞,係助詞,*,*,*,*,は,ハ,ワ\nスペース\t名詞,一般,*,*,*,*,スペース,スペース,スペース\nＸ\t記号,アルファベット,*,*,*,*,Ｘ,エックス,エックス\nファンデーション\t名詞,一般,*,*,*,*,ファンデーション,ファンデーション,ファンデーション\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n明日\t名詞,副詞可能,*,*,*,*,明日,アシタ,アシタ\n出\t動詞,自立,*,*,一段,連用形,出る,デ,デ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nき\t動詞,非自立,*,*,カ変・クル,連用形,くる,キ,キ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nね\t助詞,終助詞,*,*,*,*,ね,ネ,ネ\n五\t名詞,数,*,*,*,*,五,ゴ,ゴ\nエックスプライズファウンデーション\t名詞,一般,*,*,*,*,*\nで\t助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nよい\t形容詞,非自立,*,*,形容詞・アウオ段,基本形,よい,ヨイ,ヨイ\n宇宙\t名詞,一般,*,*,*,*,宇宙,ウチュウ,ウチュー\nとか\t助詞,並立助詞,*,*,*,*,とか,トカ,トカ\n例えば\t接続詞,*,*,*,*,*,例えば,タトエバ,タトエバ\n有人\t名詞,一般,*,*,*,*,有人,ユウジン,ユージン\n宇宙\t名詞,一般,*,*,*,*,宇宙,ウチュウ,ウチュー\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n初めて\t副詞,一般,*,*,*,*,初めて,ハジメテ,ハジメテ\n民間\ ...

# %%
lines = result.split('\n')
words = []#「名詞」と「動詞」を格納するリスト
for line in lines:
    feature = line.split('\t')
    if len(feature) == 2: #'EOS'と''を省く
        info = feature[1].split(',')
        hinshi = info[0]
        if hinshi in ('名詞'):
            if info[6] != '*' :
                if info[6] != 'ん':
                    if info[6] != 'こと':
                        if info[6] != 'どこ':
                            if info[6] != '何':
                                words.append(info[6])
                    
            

words
        
        

ngram_list = ([(words[i], words[i+1]) for i in range(len(words)-1)])
for n_word in ngram_list:
        if n_word in termFreq:
            termFreq[n_word] += 1
        else:
            termFreq[n_word] = 1
            
term_list = []
count_list = []
for term, count in termFreq.items():
    term_list.append(term)
    count_list.append(count)

s = pd.DataFrame({
 'Count':count_list,
 'List':term_list
 })

s = s.sort_values('Count', ascending=False)
pd.get_option("display.max_rows", 2000)
s.head(60)


    
# print(ngram_list)
# Out:
#      Count          List
# 63      10        (二, 千)
# 68      10        (五, 年)
# 42       8        (令, 和)
# 247      8      (それ, それ)
# 4        6        (二, 十)
# 287      6       (三, カ月)
# 60       6        (十, 五)
# 338      6       (誕生, 日)
# 202      6        (千, 五)
# 215      4     (ライブ, ドア)
# 69       4        (年, 前)
# 36       4        (十, 二)
# 94       4        (二, 年)
# 128      4        (俺, 方)
# 428      4      (交通, 事故)
# 395      4      (検察, 歴史)
# 469      4     (操作, こいつ)
# 406      4      (日本, 一番)
# 476      4      (警察, 検察)
# 152      4     (みたい, 感じ)
# 320      4        (一, 人)
# 269      4   (ボード, メンバー)
# 356      2        (後, 高)
# 367      2      (感じ, 無理)
# 373      2   (戦場, パーティー)
# 358      2      (あれ, 後手)
# 372      2      (全部, 戦場)
# 371      2     (ページ, 全部)
# 370      2    (ラリー, ページ)
# 369      2     (ころ, ラリー)
# 368      2      (無理, ころ)
# 352      2        (水, 十)
# 353      2       (二, ため)
# 366      2       (ら, 感じ)
# 374      2  (パーティー, その後)
# 365      2       (電話, ら)
# 364      2       (年, 電話)
# 357      2       (高, あれ)
# 362      2     (プレー, 景気)
# 359      2       (後手, 番)
# 361      2   (ガーベラ, プレー)
# 360      2     (番, ガーベラ)
# 354      2      (ため, 未来)
# 355      2       (未来, 後)
# 363      2       (景気, 二)
# 379      2       (カ月, 三)
# 375      2    (その後, いずれ)
# 393      2     (仕組み, 検察)
# 409      2       (時, 検察)
# 408      2       (検査, 時)
# 407      2      (一番, 検査)
# 405      2      (歴史, 日本)
# 404      2       (俺, 検察)
# 403      2     (コメント, 俺)
# 402      2    (相当, コメント)
# 401      2      (とき, 相当)
# 400      2      (事件, とき)
# 399      2     (不動産, 事件)
# 398      2      (株, 不動産)
# 397      2        (前, 株)

# %%
target_combinations = []
target_combinations.extend(ngram_list)
combi_count = collections.Counter(target_combinations)
word_associates = []
for key, value in combi_count.items():
    word_associates.append([key[0], key[1], value])
word_associates = pd.DataFrame(word_associates, columns=['word1', 'word2', 'intersection_count'])


#  和集合の計算 n(A ∪ B) = n(A) + n(B) - n(A ∩ B) を利用
#  それぞれの単語の出現回数を計算
target_words = []
for word in target_combinations:
    target_words.extend(word)

word_count = collections.Counter(target_words)
word_count = [[key, value] for key, value in word_count.items()]
word_count = pd.DataFrame(word_count, columns=['word', 'count'])

#  単語の組合せの出現回数のデータにそれぞれの単語の出現回数を結合
word_associates = pd.merge(word_associates, word_count, left_on='word1', right_on='word', how='left')
word_associates.drop(columns=['word'], inplace=True)
word_associates.rename(columns={'count': 'count1'}, inplace=True)
word_associates = pd.merge(word_associates, word_count, left_on='word2', right_on='word', how='left')
word_associates.drop(columns=['word'], inplace=True)
word_associates.rename(columns={'count': 'count2'}, inplace=True)

word_associates['union_count'] = word_associates['count1'] + word_associates['count2'] - word_associates['intersection_count']
word_associates['jaccard_coefficient'] = word_associates['intersection_count'] / word_associates['union_count']

print('Jaccard係数の算出')
word_associates.head(60)
# Out:
# Jaccard係数の算出
#        word1     word2  intersection_count  count1  count2  union_count  \
# 0       それぞれ        ぼく                   1       1       2            2
# 1         ぼく         や                   1       2       2            3
# 2          や        企画                   1       2       2            3
# 3         企画         二                   1       2      30           31
# 4          二         十                   3      30      16           43
# 5          十         分                   1      16       2           17
# 6          分         一                   1       2       8            9
# 7          一         本                   1       8       4           11
# 8          本        勝負                   1       4       2            5
# 9         勝負        法力                   1       2       2            3
# 10        法力      スタート                   1       2       2            3
# 11      スタート        物体                   1       2       2            3
# 12        物体        条例                   1       2       2            3
# 13        条例        意味                   1       2       2            3
# 14        意味        宇宙                   1       2      10           11
# 15        宇宙        戦い                   1      10       2           11
# 16        戦い        日本                   1       2      14           15
# 17        日本        忠勝                   1      14       2           15
# 18        忠勝         俺                   1       2      26           27
# 19         俺        田中                   1      26       2           27
# 20        田中         笑                   1       2       2            3
# 21         笑         方                   1       2      12           13
# 22         方        部類                   1      12       2           13
# 23        部類        これ                   1       2      10           11
# 24        これ        以降                   1      10       4           13
# 25        以降        以降                   1       4       4            7
# 26        以降         僕                   1       4      12           15
# 27         僕      スペース                   1      12       4           15
# 28      スペース  ファンデーション                   1       4       2            5
# 29  ファンデーション        明日                   1       2       4            5
# 30        明日         五                   1       4      18           21
# 31         五        宇宙                   1      18      10           27
# 32        宇宙        有人                   1      10       2           11
# 33        有人        宇宙                   1       2      10           11
# 34        宇宙        民間                   1      10       2           11
# 35        民間         十                   1       2      16           17
# 36         十         二                   2      16      30           44
# 37         二         人                   1      30      20           49
# 38         人        財団                   1      20       2           21
# 39        財団        そこ                   1       2      18           19
# 40        そこ      ブリッジ                   1      18       2           19
# 41      ブリッジ         令                   1       2       8            9
# 42         令         和                   4       8       8           12
# 43         和        空色                   1       8       2            9
# 44        空色        関係                   1       2       4            5
# 45        関係        盛り                   1       4       2            5
# 46        盛り         色                   1       2       2            3
# 47         色         二                   1       2      30           31
# 48         十         七                   1      16       2           17
# 49         七         度                   1       2       4            5
# 50         度        変態                   1       4       2            5
# 51        変態        会長                   1       2       4            5
# 52        会長         今                   1       4       4            7
# 53         今         僕                   1       4      12           15
# 54         僕        そこ                   1      12      18           29
# 55        そこ         五                   1      18      18           35
# 56         五         千                   1      18      12           29
# 57         千         万                   1      12       2           13
# 58         万         円                   1       2       2            3
# 59         円         十                   1       2      16           17
#
#     jaccard_coefficient
# 0              0.500000
# 1              0.333333
# 2              0.333333
# 3              0.032258
# 4              0.069767
# 5              0.058824
# 6              0.111111
# 7              0.090909
# 8              0.200000
# 9              0.333333
# 10             0.333333
# 11             0.333333
# 12             0.333333
# 13             0.333333
# 14             0.090909
# 15             0.090909
# 16             0.066667
# 17             0.066667
# 18             0.037037
# 19             0.037037
# 20             0.333333
# 21             0.076923
# 22             0.076923
# 23             0.090909
# 24             0.076923
# 25             0.142857
# 26             0.066667
# 27             0.066667
# 28             0.200000
# 29             0.200000
# 30             0.047619
# 31             0.037037
# 32             0.090909
# 33             0.090909
# 34             0.090909
# 35             0.058824
# 36             0.045455
# 37             0.020408
# 38             0.047619
# 39             0.052632
# 40             0.052632
# 41             0.111111
# 42             0.333333
# 43             0.111111
# 44             0.200000
# 45             0.200000
# 46             0.333333
# 47             0.032258
# 48             0.058824
# 49             0.200000
# 50             0.200000
# 51             0.200000
# 52             0.142857
# 53             0.066667
# 54             0.034483
# 55             0.028571
# 56             0.034483
# 57             0.076923
# 58             0.333333
# 59             0.058824

# %%
u = word_associates['word1'].unique().tolist()
termFreq = {}
for label in u:
    df_1 = word_associates[word_associates['word1'] == label]
    termFreq[label] = len(df_1)

term_list = []
count_list = []
for term, count in termFreq.items():
    term_list.append(term)
    count_list.append(count)

s = pd.DataFrame({
 'Count':count_list,
 'List':term_list
 })

s = s.sort_values('Count', ascending=False)
pd.get_option("display.max_rows", 2000)
s
# Out:
#      Count   List
# 19      12      俺
# 103     11     それ
# 33      10      人
# 35       9     そこ
# 52       9      年
# ..     ...    ...
# 144      1      数
# 145      1  プランナー
# 146      1  フリーター
# 150      1     矢先
# 330      1     場合
#
# [331 rows x 2 columns]

# %%
s.mean()
# Out:
# Count    2.088339
# dtype: float64

# %%
s.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a21840c50>]],
#       dtype=object)

# %%
len(s)
# Out:
# 566

# %%
len(word_associates['word1'].value_counts())
# Out:
# 332

# %%
n_word_lower = 1
edge_threshold = 0.01

word_associates.query('count1 >= @n_word_lower & count2 >= @n_word_lower', inplace=True)
word_associates.rename(columns={'word1':'node1', 'word2':'node2', 'jaccard_coefficient':'value'}, inplace=True)

##  共起ネットワークを表示する関数
def plot_network(data, edge_threshold=0., fig_size=(15, 15), file_name=None, dir_path=None):

    nodes = list(set(data['node1'].tolist()+data['node2'].tolist()))

    G = nx.Graph()
    #  頂点の追加
    G.add_nodes_from(nodes)

    #  辺の追加
    #  edge_thresholdで枝の重みの下限を定めている
    for i in range(len(data)):
        row_data = data.iloc[i]
        if row_data['value'] > edge_threshold:
            G.add_edge(row_data['node1'], row_data['node2'], weight=row_data['value'])

    # 孤立したnodeを削除
    isolated = [n for n in G.nodes if len([i for i in nx.all_neighbors(G, n)]) == 0]
    for n in isolated:
        G.remove_node(n)

    plt.figure(figsize=fig_size)
    pos = nx.spring_layout(G, k=0.3)  # k = node間反発係数

    pr = nx.pagerank(G)

    # nodeの大きさ
    nx.draw_networkx_nodes(G, pos, node_color=list(pr.values()),
                           cmap=plt.cm.Reds,
                           alpha=0.7,
                           node_size=[60000*v for v in pr.values()])

    # 日本語ラベル
    nx.draw_networkx_labels(G, pos, fontsize=14, font_family='Hiragino Maru Gothic Pro', font_weight="bold")

    # エッジの太さ調節
    edge_width = [d["weight"] * 10 for (u, v, d) in G.edges(data=True)]
    nx.draw_networkx_edges(G, pos, alpha=0.4, edge_color="black", width=edge_width)

    plt.axis('off')

    if file_name is not None:
        if dir_path is None:
            dir_path = Path('.').joinpath('image')
        if not dir_path.exists():
            dir_path.mkdir(parents=True)
        plt.savefig(dir_path.joinpath(file_name), bbox_inches="tight")
        
plot_network(data=word_associates, edge_threshold=edge_threshold)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# # 前処理

# %%
for n_word in ngram_list:
    if n_word in termFreq:
        termFreq[n_word] += 1
    else:
        termFreq[n_word] = 1
            
#     for word in words:
#         if word in termFreq:
#             termFreq[word] += 1
#         else:
#             termFreq[word] = 1
            
#     sentences.append(words)
    
# sentences = [sentence for sentence in sentences if len(sentence) > 1]
# sentence_combinations = [list(itertools.combinations(sentence, 2)) for sentence in sentences]
# sentence_combinations = [[tuple(sorted(words)) for words in sentence] for sentence in sentence_combinations]
# print('単語の組合せ')
# for combinations in sentence_combinations[:20]:
#     print(combinations)

# %%
term_list = []
count_list = []
for term, count in termFreq.items():
    term_list.append(term)
    count_list.append(count)

s = pd.DataFrame({
 'Count':count_list,
 'List':term_list
 })

s = s.sort_values('Count', ascending=False)

# %%
pd.get_option("display.max_rows", 2000)
s.head(60)
# Out:
#       Count        List
# 80       16     (好き, な)
# 346      15     (し, てる)
# 492      14      (て, た)
# 542      14     (結婚, し)
# 169      12     (た, です)
# 168      12     (あっ, た)
# 857      12     (そう, だ)
# 616      11   (楽しかっ, た)
# 198      11    (こと, ない)
# 77       10    (はい, はい)
# 326      10      (し, た)
# 32       10     (だっ, た)
# 468      10      (し, て)
# 429      10    (旦那, さん)
# 1840      9      (一, 人)
# 123       9    (ない, です)
# 264       9  (お, ばあちゃん)
# 577       8     (22, 歳)
# 224       8      (二, 十)
# 622       8      (二, 人)
# 197       8     (た, こと)
# 21        7     (言わ, れ)
# 9         7    (そう, です)
# 152       7     (た, そう)
# 122       7     (し, ない)
# 456       7     (仕事, し)
# 945       7     (し, たい)
# 303       7      (な, だ)
# 69        7      (三, 時)
# 535       6    (です, はい)
# 603       6     (な, こと)
# 646       6      (何, し)
# 551       6      (何, 歳)
# 1119      6    (はい, そう)
# 135       6    (あっ, たら)
# 1147      6     (だ, はい)
# 569       5     (て, ない)
# 1089      5     (人, いる)
# 58        5     (お, やつ)
# 34        5    (でしょ, う)
# 121       5     (こと, し)
# 154       5     (なっ, た)
# 1563      5     (でき, た)
# 29        5     (若い, 頃)
# 16        5      (い, た)
# 89        4     (で, ない)
# 105       4     (たら, 何)
# 210       4     (来, てる)
# 96        4    (な, 食べ物)
# 131       4     (し, ます)
# 339       4     (いっ, た)
# 982       4    (そう, やっ)
# 534       4    (よかっ, た)
# 66        4    (あり, ます)
# 1531      4     (た, はい)
# 200       4    (そんな, の)
# 174       4     (何, あっ)
# 51        4      (た, の)
# 1166      4   (そんな, こと)
# 41        4     (食べ, た)

# %% [markdown]
# # 単語間の重みを測定
# <h2>Jaccard係数=n(A∩B)/n(A∪B)を使う</h2>

# %%
target_combinations = []
for sentence in sentence_combinations:
    target_combinations.extend(sentence)

##------------------------------------  Jaccard係数を求める
# Jaccard係数 = n(A ∩ B) / n(A ∪ B)

#  直積の計算（同じ文内にある２つの単語の出現回数を計算）
combi_count = collections.Counter(target_combinations)

#  単語の組合せと出現回数のデータフレームを作る
word_associates = []
for key, value in combi_count.items():
    word_associates.append([key[0], key[1], value])

word_associates = pd.DataFrame(word_associates, columns=['word1', 'word2', 'intersection_count'])

#  和集合の計算 n(A ∪ B) = n(A) + n(B) - n(A ∩ B) を利用
#  それぞれの単語の出現回数を計算
target_words = []
for word in target_combinations:
    target_words.extend(word)

word_count = collections.Counter(target_words)
word_count = [[key, value] for key, value in word_count.items()]
word_count = pd.DataFrame(word_count, columns=['word', 'count'])

#  単語の組合せの出現回数のデータにそれぞれの単語の出現回数を結合
word_associates = pd.merge(word_associates, word_count, left_on='word1', right_on='word', how='left')
word_associates.drop(columns=['word'], inplace=True)
word_associates.rename(columns={'count': 'count1'}, inplace=True)
word_associates = pd.merge(word_associates, word_count, left_on='word2', right_on='word', how='left')
word_associates.drop(columns=['word'], inplace=True)
word_associates.rename(columns={'count': 'count2'}, inplace=True)

word_associates['union_count'] = word_associates['count1'] + word_associates['count2'] - word_associates['intersection_count']
word_associates['jaccard_coefficient'] = word_associates['intersection_count'] / word_associates['union_count']

print('Jaccard係数の算出')
word_associates.head(60)
# Out:
# Jaccard係数の算出
#    word1 word2  intersection_count  count1  count2  union_count  \
# 0     ある    うち                   2     132      57          187
# 1    上がる    明日                   2      10      59           67
# 2      え    明日                   2     206      59          263
# 3    小さい    明日                   2      20      59           77
# 4     明日     見                   2      59      52          109
# 5     たん    明日                   2      25      59           82
# 6      え   上がる                   2     206      10          214
# 7    上がる   小さい                   2      10      20           28
# 8    上がる     見                   2      10      52           60
# 9     たん   上がる                   2      25      10           33
# 10     え   小さい                   2     206      20          224
# 11     え     見                   2     206      52          256
# 12     え    たん                   2     206      25          229
# 13   小さい     見                   2      20      52           70
# 14    たん   小さい                   2      25      20           43
# 15    たん     見                   2      25      52           75
# 16  お母さん    そう                   2      38     433          469
# 17  お母さん    です                   2      38     792          828
# 18    そう    です                  14     433     792         1211
# 19   みんな   小さい                   1      47      20           66
# 20     前   小さい                   1      81      20          100
# 21    あれ   小さい                   1      81      20          100
# 22     し   小さい                   2     832      20          850
# 23     い   小さい                   1     141      20          160
# 24     た   小さい                   2    1283      20         1301
# 25   みんな     前                   2      47      81          126
# 26    あれ   みんな                   2      81      47          126
# 27     し   みんな                   3     832      47          876
# 28     い   みんな                   2     141      47          186
# 29     た   みんな                   2    1283      47         1328
# 30    あれ     前                   2      81      81          160
# 31     し     前                   2     832      81          911
# 32     い     前                   2     141      81          220
# 33     た     前                   2    1283      81         1362
# 34    あれ     し                   6      81     832          907
# 35    あれ     い                   2      81     141          220
# 36    あれ     た                   3      81    1283         1361
# 37     い     し                   6     141     832          967
# 38     し     た                  35     832    1283         2080
# 39     い     た                  10     141    1283         1414
# 40    いや  そんなに                   2     184     126          308
# 41    いや    そう                   6     184     433          611
# 42    いや    言わ                   3     184      64          245
# 43    いや     れ                   3     184      81          262
# 44    いや   ちゃん                   2     184      64          246
# 45    いや     な                   6     184     517          695
# 46    そう  そんなに                   2     433     126          557
# 47  そんなに    言わ                   2     126      64          188
# 48  そんなに     れ                   2     126      81          205
# 49  そんなに   ちゃん                   2     126      64          188
# 50  そんなに     な                   4     126     517          639
# 51    そう    言わ                   5     433      64          492
# 52    そう     れ                   6     433      81          508
# 53    そう   ちゃん                   3     433      64          494
# 54    そう     な                  10     433     517          940
# 55     れ    言わ                   8      81      64          137
# 56   ちゃん    言わ                   2      64      64          126
# 57     な    言わ                   3     517      64          578
# 58   ちゃん     れ                   2      64      81          143
# 59     な     れ                   3     517      81          595
#
#     jaccard_coefficient
# 0              0.010695
# 1              0.029851
# 2              0.007605
# 3              0.025974
# 4              0.018349
# 5              0.024390
# 6              0.009346
# 7              0.071429
# 8              0.033333
# 9              0.060606
# 10             0.008929
# 11             0.007812
# 12             0.008734
# 13             0.028571
# 14             0.046512
# 15             0.026667
# 16             0.004264
# 17             0.002415
# 18             0.011561
# 19             0.015152
# 20             0.010000
# 21             0.010000
# 22             0.002353
# 23             0.006250
# 24             0.001537
# 25             0.015873
# 26             0.015873
# 27             0.003425
# 28             0.010753
# 29             0.001506
# 30             0.012500
# 31             0.002195
# 32             0.009091
# 33             0.001468
# 34             0.006615
# 35             0.009091
# 36             0.002204
# 37             0.006205
# 38             0.016827
# 39             0.007072
# 40             0.006494
# 41             0.009820
# 42             0.012245
# 43             0.011450
# 44             0.008130
# 45             0.008633
# 46             0.003591
# 47             0.010638
# 48             0.009756
# 49             0.010638
# 50             0.006260
# 51             0.010163
# 52             0.011811
# 53             0.006073
# 54             0.010638
# 55             0.058394
# 56             0.015873
# 57             0.005190
# 58             0.013986
# 59             0.005042

# %%
jaccard_coefficients = word_associates['jaccard_coefficient']
group_numbers = []
for coefficient in jaccard_coefficients:
    if coefficient < 0.003:
        group_numbers.append(0)
    elif coefficient < 0.006:
        group_numbers.append(1)
    elif coefficient < 0.009:
        group_numbers.append(2)
    elif coefficient < 0.012:
        group_numbers.append(3)
    else:
        group_numbers.append(4)
word_associates['group_number'] = group_numbers

word_associates_group_sum = word_associates.groupby('group_number').count()
word_associates_group_sum.reset_index(inplace=True)
print(word_associates_group_sum.loc[:, ['group_number', 'word2']])
print('')

sns.pairplot(hue='group_number', data=word_associates.sample(800).loc[:, ['count1', 'count2', 'group_number']])
# plt.savefig(image_dir_path.joinpath(base_file_name+'_jaccard_group_plot.png'))
# Out:
#    group_number  word2
# 0             0   2339
# 1             1   2786
# 2             2   1417
# 3             3    954
# 4             4   2266
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
n_word_lower = 20
edge_threshold = 0.01

word_associates.query('count1 >= @n_word_lower & count2 >= @n_word_lower', inplace=True)
word_associates.rename(columns={'word1':'node1', 'word2':'node2', 'jaccard_coefficient':'value'}, inplace=True)

##  共起ネットワークを表示する関数
def plot_network(data, edge_threshold=0., fig_size=(15, 15), file_name=None, dir_path=None):

    nodes = list(set(data['node1'].tolist()+data['node2'].tolist()))

    G = nx.Graph()
    #  頂点の追加
    G.add_nodes_from(nodes)

    #  辺の追加
    #  edge_thresholdで枝の重みの下限を定めている
    for i in range(len(data)):
        row_data = data.iloc[i]
        if row_data['value'] > edge_threshold:
            G.add_edge(row_data['node1'], row_data['node2'], weight=row_data['value'])

    # 孤立したnodeを削除
    isolated = [n for n in G.nodes if len([i for i in nx.all_neighbors(G, n)]) == 0]
    for n in isolated:
        G.remove_node(n)

    plt.figure(figsize=fig_size)
    pos = nx.spring_layout(G, k=0.3)  # k = node間反発係数

    pr = nx.pagerank(G)

    # nodeの大きさ
    nx.draw_networkx_nodes(G, pos, node_color=list(pr.values()),
                           cmap=plt.cm.Reds,
                           alpha=0.7,
                           node_size=[60000*v for v in pr.values()])

    # 日本語ラベル
    nx.draw_networkx_labels(G, pos, fontsize=14, font_family='Hiragino Maru Gothic Pro', font_weight="bold")

    # エッジの太さ調節
    edge_width = [d["weight"] * 100 for (u, v, d) in G.edges(data=True)]
    nx.draw_networkx_edges(G, pos, alpha=0.4, edge_color="darkgrey", width=edge_width)

    plt.axis('off')

    if file_name is not None:
        if dir_path is None:
            dir_path = Path('.').joinpath('image')
        if not dir_path.exists():
            dir_path.mkdir(parents=True)
        plt.savefig(dir_path.joinpath(file_name), bbox_inches="tight")
        
plot_network(data=word_associates, edge_threshold=edge_threshold)
